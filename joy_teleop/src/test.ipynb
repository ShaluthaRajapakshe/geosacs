# %%
import torch

# %%
model_dict = torch.load('../models/CAE_model_lio_updated', map_location='cpu')

# %%
model_dict
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[ 4.0894e-01,  8.4992e-01, -7.8219e-01, -8.8111e-01,  1.7415e+00,
#                         7.5431e-01,  2.5609e-02,  9.2869e-02, -1.2111e-01, -1.2236e-01,
#                         1.7880e-01,  8.4031e-02],
#                       [-1.3724e-02,  5.7946e-01, -1.2003e+00, -1.1026e+00,  4.4793e-01,
#                         2.4889e+00,  1.6579e-02,  1.2769e-01, -1.8196e-01, -1.9135e-01,
#                         4.1711e-02,  2.7566e-01],
#                       [-2.0423e-01, -2.4472e+00, -1.0050e+00,  1.0689e+00,  2.0148e-01,
#                        -1.2513e+00,  1.3382e-02, -2.4087e-01, -8.6336e-02,  1.1595e-01,
#                         7.4535e-03, -1.2558e-01],
#                       [-7.5379e-02,  9.7226e-01,  3.7447e-01, -1.3148e+00,  1.1273e-01,
#                         5.8426e-01,  1.3095e-02,  4.3299e-02,  5.6121e-03, -5.9447e-02,
#                        -8.9743e-02,  3.0626e-03],
# ...

# %%
# !pwd
# Out:
# /home/shalutha/geosacs_ws/src/geosacs/joy_teleop/src
